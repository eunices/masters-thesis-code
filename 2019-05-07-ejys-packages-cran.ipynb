# %%
import pandas as pd
import re
from pprint import pprint 
from datetime import date, datetime as dt
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_colwidth', -1)

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
date = date.today()
# date_cran = dt(2019, 1, 1).date()
date_cran = date.today()

# %% [markdown]
# ## Scrape from cran

# %%
url = 'https://cran.r-project.org/web/packages/available_packages_by_name.html'
page = requests.get(url)

# Ensure kaspersky is turned off

# %%
html = BeautifulSoup(page.text, 'html.parser')
table = html.find('table', {'summary': 'Available CRAN packages by name.'})
li1 = [x for x in table.find_all('tr')]
li2a = [x.find_all('td')[0].text for x in li1 if len(x.find_all('td')) == 2]
li2b = [re.sub('\\n', ' ', x.find_all('td')[1].text) for x in li1 if len(x.find_all('td')) == 2]
li2c = [re.sub('..\/..\/web/packages', 'https://cran.r-project.org/web/packages', x.find('a')['href']) 
            for x in li1 if len(x.find_all('td')) == 2]

# %%
df_out = pd.DataFrame({'name': li2a, 'description': li2b, 'url': li2c})
df_out.head()
# Out:
#        name  \
# 0  A3
# 1  abbyyR
# 2  abc
# 3  abc.data
# 4  ABC.RAP
#
#                                                                description  \
# 0  Accurate, Adaptable, and Accessible Error Metrics for Predictive Models
# 1  Access to Abbyy Optical Character Recognition (OCR) API
# 2  Tools for Approximate Bayesian Computation (ABC)
# 3  Data Only: Tools for Approximate Bayesian Computation (ABC)
# 4  Array Based CpG Region Analysis Pipeline
#
#                                                            url
# 0  https://cran.r-project.org/web/packages/A3/index.html
# 1  https://cran.r-project.org/web/packages/abbyyR/index.html
# 2  https://cran.r-project.org/web/packages/abc/index.html
# 3  https://cran.r-project.org/web/packages/abc.data/index.html
# 4  https://cran.r-project.org/web/packages/ABC.RAP/index.html

# %%
# Write data out
df_out.to_csv(f'data/01-in/cran-packages-{date}.csv', index=False)

# %% [markdown]
# ## Process data

# %%
# Read/mangle dataframe
df = pd.read_csv(f'data/01-in/cran-packages-{date_cran}.csv', encoding='latin-1')
print(df.shape)
df = df[~df.name.isnull()]
print(df.shape)

# Convert to lower for querying purposes
df = df.assign(name_lower = df.name.str.lower())
df = df.assign(description_lower = df.description.str.lower())
# Out:
# (14188, 3)
# (14188, 3)

# %% [markdown]
# Packages captured from https://cran.r-project.org on 7 May 2019.

# %%
# Testing that it works
print(df[df.name_lower == 'inext']['description_lower'])
# Out:
# 5642    interpolation and extrapolation for species diversity
# Name: description_lower, dtype: object

# %%
# Figuring out keywords to use
pd.set_option('display.max_colwidth', 100)
df[df.description_lower.str.contains('species')][['name', 'description']]
# Out:
#                       name  \
# 156              AGHmatrix
# 640             BarcodingR
# 671               BatchMap
# 869               betalink
# 1018               biomod2
# 1199              bossMaps
# 1233             breakaway
# 1873               coexist
# 2056               cooccur
# 2838                 dismo
# 2876               divagis
# 2882    DiversityOccupancy
# 2973             downscale
# 3710              FactorsR
# 3939        fishkirkko2015
# 4201              funbarRF
# 4254              fuzzySim
# 4286                gambin
# 5079                HACSim
# 5345                  hSDM
# 5421                 HyPhy
# 5637          indicspecies
# 5642                 iNEXT
# 5829                  iSDM
# 5957             jointNmix
# 6083               kissmig
# 6768                  mapr
# 6789           marinespeed
# 6858               maxlike
# 6861                maxnet
# 7146              MHCtools
# 7196               MigClim
# 7315                 mizer
# 7498                  mopa
# 7926              netassoc
# 8376               opticut
# 8387         optimos.prime
# 8455               originr
# 8470   OscillatorGenerator
# 8868            perspectev
# 9203             PolyPatEx
# 9349               preseqR
# 9887          rangeBuilder
# 9889    rangeModelMetadata
# 9890           rangemodelR
# 9924                Rarity
# 10025               rcites
# 10279             redlistr
# 10560                 rich
# 10958           Rphylopars
# 11071                  RSE
# 11305               SADISA
# 11307                 sads
# 11369                 sars
# 11501                  sdm
# 11502              SDMPlay
# 11503        sdmpredictors
# 11504             SDMTools
# 11505          sdmvspecies
# 11512               sdStaf
# 11570               Select
# 11715                 shar
# 11720                sharx
# 12155                 spaa
# 12169               SpadeR
# 12304              SPECIES
# 12305           SpeciesMix
# 12319          SPEDInstabR
# 12343               spider
# 12382                spocc
# 12400                sprex
# 12416               spThin
# 12450                 SSDM
# 12452             ssdtools
# 12476                 sssc
# 12496             stagePop
# 12938           Taxonstand
# 13275                  TR8
# 13294               traits
# 13295           Traitspace
# 13610                 usdm
# 13697         VDJgermlines
# 13761       virtualspecies
# 13833              wallace
# 14000                worms
# 14001               worrms
# 14179                 zoon
#
#                                                                                                description
# 156                                            Relationship Matrices for Diploid and Autopolyploid Species
# 640                                                              Species Identification using DNA Barcodes
# 671                          Software for the Creation of High Density Linkage Maps in Outcrossing Species
# 869                                                                 Beta-Diversity of Species Interactions
# 1018                                                   Ensemble Platform for Species Distribution Modeling
# 1199            Convert Binary Species Range Maps into Continuous Surfaces Based on Distance to Range Edge
# 1233                                                              Species Richness Estimation and Modeling
# 1873                                                             Species coexistence modeling and analysis
# 2056                                                     Probabilistic Species Co-Occurrence Analysis in R
# 2838                                                                         Species Distribution Modeling
# 2876                           Provides tools for quality checks of georeferenced plant species accessions
# 2882                                      Building Diversity Models from Multiple Species Occupancy Models
# 2973                                                                         Downscaling Species Occupancy
# 3710                                              Identification of the Factors Affecting Species Richness
# 3939                                  Dataset of Measurements of Fish Species at Kirkkojarvi Lake, Finland
# 4201                                    Fungal Species Identification using DNA Barcode with Random Forest
# 4254                                                             Fuzzy Similarity in Species Distributions
# 4286                                               Fit the Gambin Model to Species Abundance Distributions
# 5079                                     Iterative Extrapolation of Species' Haplotype Accumulation Curves
# 5345                                                     Hierarchical Bayesian Species Distribution Models
# 5421                                Macroevolutionary phylogentic analysis of species trees and gene trees
# 5637                                                      Relationship Between Species and Groups of Sites
# 5642                                                 Interpolation and Extrapolation for Species Diversity
# 5829                                                               Invasive Species Distribution Modelling
# 5957                                                    Joint N-Mixture Models for Site-Associated Species
# 6083                                                              a Keep It Simple Species Migration Model
# 6768                                                                     Visualize Species Occurrence Data
# 6789                           Benchmark Data Sets and Functions for Marine Species Distribution Modelling
# 6858      Model Species Distributions by Estimating the Probability of Occurrence Using Presence-Only Data
# 6861                                            Fitting 'Maxent' Species Distribution Models with 'glmnet'
# 7146                                                             Analysis of MHC Data in Non-Model Species
# 7196                                               Implementing dispersal into species distribution models
# 7315                                                            Multi-Species sIZE Spectrum Modelling in R
# 7498                                                    Species Distribution MOdeling with Pseudo-Absences
# 7926                                             Inference of Species Associations from Co-Occurrence Data
# 8376                                  Likelihood Based Optimal Partitioning and Indicator Species Analysis
# 8387                              Optimos Prime Helps Calculate Autoecological Data for Biological Species
# 8455                                                                Fetch Species Origin Data from the Web
# 8470                            Generation of Customizable, Discretized Time Series of Oscillating Species
# 8868                                                         Permutation of Species During Turnover Events
# 9203                                                          Paternity Exclusion in Autopolyploid Species
# 9349                                                                Predicting Species Accumulation Curves
# 9887   Occurrence Filtering, Geographic and Taxonomic Standardization and Generation of Species Range P...
# 9889                            Provides Templates for Metadata Files Associated with Species Range Models
# 9890                                                                Mid-Domain Effect and Species Richness
# 9924                                  Calculation of Rarity Indices for Species and Assemblages of Species
# 10025                                                                 R Interface to the Species+ Database
# 10279                                                Tools for the IUCN Red List of Ecosystems and Species
# 10560                                                             Computes and Compares Species Richnesses
# 10958                         Phylogenetic Comparative Tools for Missing Data and Within-Species Variation
# 11071                                                   Number of Newly Discovered Rare Species Estimation
# 11305                                  Species Abundance Distributions with Independent-Species Assumption
# 11307                                        Maximum Likelihood Models for Species Abundance Distributions
# 11369                          Fit and Compare Species-Area Relationship Models Using Multimodel Inference
# 11501                                                                       Species Distribution Modelling
# 11502                                                            Species Distribution Modelling Playground
# 11503                                                    Species Distribution Modelling Predictor Datasets
# 11504  Species Distribution Modelling Tools: Tools for processing data associated with species distribu...
# 11505                                            Create Virtual Species for Species Distribution Modelling
# 11512                                                     Species Distribution and Stability Future Models
# 11570                                          Determines Species Probabilities Based on Functional Traits
# 11715                                                                         Species-Habitat Associations
# 11720                                     Models and Data Sets for the Study of Species-Area Relationships
# 12155                                                                         SPecies Association Analysis
# 12169                                          Species-Richness Prediction and Diversity Estimation with R
# 12304                                                  Statistical package for species richness estimation
# 12305                                                                    Fit Mixtures of Archetype Species
# 12319  Estimation of the Relative Importance of Factors Affecting Species Distribution Based on Stabili...
# 12343                                                                  Species Identity and Evolution in R
# 12382                                                         Interface to Species Occurrence Data Sources
# 12400                                                 Calculate Species Richness and Extrapolation Metrics
# 12416            Functions for Spatial Thinning of Species Occurrence Records for Use in Ecological Models
# 12450                                                               Stacked Species Distribution Modelling
# 12452                                                                    Species Sensitivity Distributions
# 12476                                                          Same Species Sample Contamination Detection
# 12496                   Modelling the Population Dynamics of a Stage-Structured Species in Continuous Time
# 12938                                                     Taxonomic Standardization of Plant Species Names
# 13275                                      A Tool for Downloading Functional Traits Data for Plant Species
# 13294                                                               Species Trait Data from Around the Web
# 13295                               A Predictive Model for Trait Based Community Assembly of Plant Species
# 13610                                                 Uncertainty Analysis for Species Distribution Models
# 13697                                       Variable, Diversity and Joining Sequences from Various Species
# 13761                                                          Generation of Virtual Species Distributions
# 13833                     A Modular Platform for Reproducible Modeling of Species Niches and Distributions
# 14000                                    Retriving Aphia Information from World Register of Marine Species
# 14001                                                      World Register of Marine Species (WoRMS) Client
# 14179                                  Reproducible, Accessible & Shareable Species Distribution Modelling

# %% [markdown]
# Looks like 'species', together with 'distribution', 'occupancy', 'diversity', 'niche', 'spatial' are important keywords. 'occurrence' are tentative.

# %%
keywords = [
    ['species', 'distribution'],
    ['SDM'],
    ['niche'],
    ['species', 'range'],
    ['species', 'occupancy'],
    ['species', 'diversity', 'extrapolation']
]

# %%
df
# Out:
#                               name  \
# 0                               A3
# 1                           abbyyR
# 2                              abc
# 3                         abc.data
# 4                          ABC.RAP
# 5                      ABCanalysis
# 6                         abcdeFBA
# 7                         ABCoptim
# 8                            ABCp2
# 9                            abcrf
# 10                        abctools
# 11                             abd
# 12                             abe
# 13                            abf2
# 14                    ABHgenotypeR
# 15                           abind
# 16                        abjutils
# 17                             abn
# 18                     abnormality
# 19                     abodOutlier
# 20                            ABPS
# 21                   AbsFilterGSEA
# 22                           AbSim
# 23                       abstractr
# 24                          abtest
# 25                        abundant
# 26                          Ac3net
# 27                             ACA
# 28                             acc
# 29                   accelerometry
# 30                    accelmissing
# 31              AcceptanceSampling
# 32                          ACCLMA
# 33                         accrual
# 34                         accrued
# 35                          accSDA
# 36                             ACD
# 37                            ACDm
# 38                        acebayes
# 39                         acepack
# 40                            ACEt
# 41                            acid
# 42                           acm4r
# 43                        ACMEeqtl
# 44                           acmeR
# 45                            ACNE
# 46                            acnr
# 47                         acopula
# 48                AcousticNDLCodeR
# 49                             acp
# 50                            aCRM
# 51                       AcrossTic
# 52                            acrt
# 53                             acs
# 54                       ACSNMineR
# 55                            acss
# 56                       acss.data
# 57                           ACSWR
# 58                           ACTCD
# 59                      Actigraphy
# 60                    ActiveDriver
# 61                 ActiveDriverWGS
# 62                  ActivePathways
# 63                        activity
# 64                   ActivityIndex
# 65              activpalProcessing
# 66                      actogrammr
# 67                          actuar
# 68                      AcuityView
# 69                             ada
# 70                          adabag
# 71                          adagio
# 72                      adamethods
# 73                   AdapEnetClass
# 74                           adapr
# 75                        AdapSamp
# 76                      adaptalint
# 77                        AdaptFit
# 78                      AdaptFitOS
# 79                      AdaptGauss
# 80                    adaptiveGPCA
# 81                AdaptiveSparsity
# 82                     adaptivetau
# 83                       adaptMCMC
# 84                         adaptMT
# 85                    adaptsmoFMRI
# 86                       adaptTest
# 87                     AdaSampling
# 88                            ADCT
# 89                          addhaz
# 90                       addhazard
# 91                      addinslist
# 92                     additiveDEA
# 93                 additivityTests
# 94                          addreg
# 95                            ADDT
# 96                            ade4
# 97                       ade4TkGUI
# 98                           adeba
# 99                        adegenet
# 100                    adegraphics
# 101                   adehabitatHR
# 102                   adehabitatHS
# 103                   adehabitatLT
# 104                   adehabitatMA
# 105                       adephylo
# 106                         adepro
# 107                      adeptdata
# 108                  AdequacyModel
# 109                     adespatial
# 110                    adfExplorer
# 111                      ADGofTest
# 112                        AdhereR
# 113                          adhoc
# 114                        adimpro
# 115                           adiv
# 116                         AdjBQR
# 117                       adjclust
# 118               adjustedcranlogs
# 119                    adklakedata
# 120                         adlift
# 121                         admisc
# 122                          AdMit
# 123                 admixturegraph
# 124                           ADMM
# 125                        ADMMnet
# 126                      ADMMsigma
# 127                         adnuts
# 128                       adoption
# 129                         adoptr
# 130                       ADPclust
# 131                           ADPF
# 132                          adpss
# 133                            ads
# 134                   AdvBinomApps
# 135                       advclust
# 136                        AdvDif4
# 137                         adwave
# 138                       adwordsR
# 139                 AEDForecasting
# 140                           aemo
# 141                            AER
# 142                    AeRobiology
# 143                             AF
# 144                            afc
# 145                          afCEC
# 146                           afex
# 147                 affluenceIndex
# 148                            AFM
# 149                     afmToolkit
# 150                           afpt
# 151                         aftgee
# 152                            AGD
# 153                            aGE
# 154                     AggregateR
# 155                    aggregation
# 156                      AGHmatrix
# 157                           agop
# 158                         AGread
# 159                          agRee
# 160              AgreementInterval
# 161                      agricolae
# 162                        agridat
# 163                   agriTutorial
# 164                      agriwater
# 165                          agrmt
# 166                        AGSDest
# 167                       agsemisc
# 168                           ahaz
# 169                        AHMbook
# 170                           ahnr
# 171                AhoCorasickTrie
# 172                            ahp
# 173                      ahpsurvey
# 174                            AHR
# 175                     AICcmodavg
# 176                            AID
# 177                          aidar
# 178                            AIG
# 179                            AIM
# 180                        aimPlot
# 181                      aire.zmvm
# 182                          airGR
# 183                  airGRteaching
# 184                       airportr
# 185                           airr
# 186                      aiRthermo
# 187                            ajv
# 188                            Ake
# 189                          akima
# 190                        akmeans
# 191                      akmedoids
# 192                          ALA4R
# 193                        alabama
# 194                       alakazam
# 195                     albopictus
# 196                            ald
# 197                          ALDqr
# 198                        ALEPlot
# 199                           aLFQ
# 200                         alfred
# 201                      AlgDesign
# 202          AlgebraicHaploPackage
# 203                    algorithmia
# 204                      alignfigR
# 205                         alineR
# 206                          allan
# 207                       allanvar
# 208                        alleHap
# 209                    allelematch
# 210                   AlleleRetain
# 211                        allelic
# 212           AllPossibleSpellings
# 213                       alluvial
# 214                         alpaca
# 215                      alphabetr
# 216                      alphahull
# 217                   alphaOutlier
# 218                   alphashape3d
# 219                      AlphaSimR
# 220                    alphastable
# 221             AlphaVantageClient
# 222                  alphavantager
# 223                           alr3
# 224                           alr4
# 225                            ALS
# 226                         ALSCPC
# 227                           ALSM
# 228                       alterryx
# 229                        altmeta
# 230                         ALTopt
# 231                           amap
# 232                       AMAP.Seq
# 233                       ambhasGW
# 234                        ambient
# 235                           AMCP
# 236                   AMCTestmakeR
# 237                          ameco
# 238                         Amelia
# 239                         amelie
# 240                           amen
# 241                AmericanCallOpt
# 242                        amerika
# 243                    AmesHousing
# 244                          AMGET
# 245                          AMIAS
# 246                       AmigaFFH
# 247                            aml
# 248                  ammistability
# 249                       AMModels
# 250           AmmoniaConcentration
# 251                         aMNLFA
# 252                         AMOEBA
# 253                          AMORE
# 254                  AmostraBrasil
# 255                           ampd
# 256                    AmpliconDuo
# 257                            AMR
# 258                            amt
# 259                      AmyloGram
# 260                        AnaCoDa
# 261                         anacor
# 262                      analogsea
# 263                       analogue
# 264                  analogueExtra
# 265              analysisPipelines
# 266                      analytics
# 267                         analyz
# 268                    AnalyzeFMRI
# 269                      AnalyzeTS
# 270                        anapuce
# 271                 AncestryMapper
# 272                  anchoredDistr
# 273                        anchors
# 274                           AnDE
# 275                        andrews
# 276                       anesrake
# 277                          anfis
# 278    AnglerCreelSurveySimulation
# 279                      angstroms
# 280                         aniDom
# 281                     anim.plots
# 282                    animalTrack
# 283                      animation
# 284                       anipaths
# 285                           anMC
# 286                           ANN2
# 287                AnnotationBustR
# 288                     AnnotLists
# 289                     AnnuityRIR
# 290                         anocva
# 291                         anoint
# 292                           ANOM
# 293                      anomalize
# 294                        anomaly
# 295                      anominate
# 296                     ANOVA.TFNs
# 297               ANOVAreplication
# 298                     ANOVAShiny
# 299                   AntAngioCOOL
# 300              antaresEditObject
# 301              antaresProcessing
# 302                    antaresRead
# 303                     antaresViz
# 304                         anthro
# 305                     AnthropMMD
# 306                  Anthropometry
# 307                      antitrust
# 308                       antiword
# 309                         AntWeb
# 310                         anyLib
# 311                        anytime
# 312                            aod
# 313                          aods3
# 314                           aoos
# 315                      Aoptbdtvc
# 316                       aoristic
# 317                            apa
# 318             ApacheLogProcessor
# 319                      apaTables
# 320                        apaText
# 321                            apc
# 322                    APCanalysis
# 323                           apcf
# 324                      apcluster
# 325                       apdesign
# 326                            ape
# 327                         apercu
# 328                           apex
# 329                          APfun
# 330                          aphid
# 331                        aplore3
# 332                        aplpack
# 333                          APML0
# 334                       apmsWAPP
# 335                           apng
# 336                         apollo
# 337                       apparent
# 338                         appell
# 339                  APPEstimation
# 340                          apple
# 341      AppliedPredictiveModeling
# 342                          appnn
# 343                   approximator
# 344                    approxmatch
# 345                        aprean3
# 346                        apricom
# 347                          aprof
# 348                          APSIM
# 349                     APSIMBatch
# 350                         apsimr
# 351                      apsrtable
# 352                            apt
# 353                           aptg
# 354                        APtools
# 355                    apTreeshape
# 356                          aqfig
# 357                            aqp
# 358                            aqr
# 359                        AquaEnv
# 360                             AR
# 361                      ar.matrix
# 362                         AR1seg
# 363                    arabicStemR
# 364                      ArArRedux
# 365                            arc
# 366                      ARCensReg
# 367                   ArchaeoChron
# 368                  ArchaeoPhases
# 369                       archdata
# 370                     archetypes
# 371                      archiDART
# 372                      archivist
# 373               archivist.github
# 374                           ArCo
# 375                          ArDec
# 376                          areal
# 377                       areaplot
# 378                        arena2r
# 379                        arf3DS4
# 380                         arfima
# 381                      ArfimaMLM
# 382                           argo
# 383                         argon2
# 384                      argonDash
# 385                         argonR
# 386                    argosfilter
# 387                       argparse
# 388                      argparser
# 389                  ArgumentCheck
# 390                           ARHT
# 391                            ari
# 392                       ARIbrain
# 393                        aricode
# 394                          arkdb
# 395                            arm
# 396                         armada
# 397                         armspp
# 398                          arnie
# 399                           AROC
# 400               aroma.affymetrix
# 401                      aroma.apd
# 402                       aroma.cn
# 403                     aroma.core
# 404                       Arothron
# 405                        ARpLMEC
# 406                 ARPobservation
# 407                           arpr
# 408                        aRpsDCA
# 409                   arrangements
# 410                       arrApply
# 411                       ArrayBin
# 412                   arrayhelpers
# 413                            ars
# 414                           arse
# 415                        arsenal
# 416                            ART
# 417                        artfima
# 418                         ARTIVA
# 419                         ARTool
# 420                           ARTP
# 421                          ARTP2
# 422                         arules
# 423                      arulesCBA
# 424                  arulesNBMiner
# 425                arulesSequences
# 426                      arulesViz
# 427                          aRxiv
# 428                          asaur
# 429                          asbio
# 430                     asciiruler
# 431               asciiSetupReader
# 432                            asd
# 433                      asdreader
# 434                     ASGS.foyer
# 435                            ash
# 436                           ashr
# 437                           asht
# 438                    AsioHeaders
# 439                           ASIP
# 440                        askpass
# 441                          aslib
# 442                          ASMap
# 443                         asnipe
# 444                         aspace
# 445                         ASPBay
# 446                           aSPC
# 447                         aspect
# 448                           aspi
# 449                           aSPU
# 450                     asremlPlus
# 451                           ASSA
# 452                 AssayCorrector
# 453                     assertable
# 454                      assertive
# 455                 assertive.base
# 456                 assertive.code
# 457                 assertive.data
# 458              assertive.data.uk
# 459              assertive.data.us
# 460            assertive.datetimes
# 461                assertive.files
# 462             assertive.matrices
# 463               assertive.models
# 464              assertive.numbers
# 465           assertive.properties
# 466           assertive.reflection
# 467                 assertive.sets
# 468              assertive.strings
# 469                assertive.types
# 470                        assertr
# 471                     assertthat
# 472                      AssetCorr
# 473                   AssetPricing
# 474                      assignPOP
# 475                         assist
# 476                      ASSISTant
# 477                       AssocAFC
# 478                       assocInd
# 479                     AssocTests
# 480                      assortnet
# 481                     AssotesteR
# 482                            AST
# 483                          aster
# 484                         aster2
# 485                          astro
# 486                     astrochron
# 487                      astrodatR
# 488                       astroFns
# 489                      astrolibR
# 490                          astsa
# 491                           asus
# 492                          asVPC
# 493                         asymLD
# 494                      asymmetry
# 495                      asympTest
# 496                     AsynchLong
# 497                         asypow
# 498                         atable
# 499                            ATE
# ...                            ...
# 13688                         vcov
# 13689                          vcr
# 13690                      vcrpart
# 13691                        vctrs
# 13692                         VDAP
# 13693                          vdg
# 13694                      Vdgraph
# 13695                       VdgRsm
# 13696                       vdiffr
# 13697                 VDJgermlines
# 13698                         vdmR
# 13699              VDSPCalibration
# 13700                  vec2dtransf
# 13701                   veccompare
# 13702                      vecsets
# 13703              VecStatGraphs2D
# 13704              VecStatGraphs3D
# 13705                     vegalite
# 13706                        vegan
# 13707                      vegan3d
# 13708                   vegawidget
# 13709                     vegclust
# 13710                      vegdata
# 13711                   vegetarian
# 13712                    vegperiod
# 13713                     vegtable
# 13714                         vein
# 13715                  velociraptr
# 13716                        velox
# 13717                      vembedr
# 13718                         venn
# 13719                  VennDiagram
# 13720                    venneuler
# 13721                    vennLasso
# 13722                     vennplot
# 13723                 verification
# 13724                     versions
# 13725                   vertexenum
# 13726             VertexSimilarity
# 13727                   VertexSort
# 13728            VeryLargeIntegers
# 13729                      vesselr
# 13730                      vetools
# 13731                         vetr
# 13732               VetResearchLMM
# 13733                         vfcp
# 13734                          VFP
# 13735                          VFS
# 13736                         VGAM
# 13737                     VGAMdata
# 13738                    VGAMextra
# 13739            VHDClassification
# 13740                        vhica
# 13741                     VICmodel
# 13742                  vietnamcode
# 13743                   viewshed3d
# 13744                          VIF
# 13745                        VIFCP
# 13746                        VIGoR
# 13747                          VIM
# 13748                       VIMGUI
# 13749                         vimp
# 13750                   VineCopula
# 13751                      vinereg
# 13752                        vines
# 13753                  violinmplot
# 13754                      vioplot
# 13755                    viopoints
# 13756                          vip
# 13757                        vipor
# 13758                         VIRF
# 13759                      viridis
# 13760                  viridisLite
# 13761               virtualspecies
# 13762                     virtuoso
# 13763                   virustotal
# 13764                       visdat
# 13765                     ViSiElse
# 13766                   visNetwork
# 13767                       visreg
# 13768                      vistime
# 13769                      visTree
# 13770                vistributions
# 13771                 visualFields
# 13772                    visualize
# 13773                      visualR
# 13774                    VisuClust
# 13775                       visvow
# 13776                         vita
# 13777                        vitae
# 13778                     vitality
# 13779                          vkR
# 13780                         vlad
# 13781                          VLF
# 13782                         VLMC
# 13783                        vMask
# 13784                          vmd
# 13785                      vmsbase
# 13786                          VNM
# 13787                     vocaldia
# 13788                   volleystat
# 13789               voronoiTreemap
# 13790                      vortexR
# 13791                  vortexRdata
# 13792                     vosonSML
# 13793                         Voss
# 13794                         vote
# 13795                    voteogram
# 13796                      votesys
# 13797                     vottrans
# 13798                       vowels
# 13799                         vows
# 13800                        voxel
# 13801                         VoxR
# 13802                          vpc
# 13803                         vqtl
# 13804                         vrcp
# 13805                      vrmlgen
# 13806                        vroom
# 13807                         VRPM
# 13808                       vrtest
# 13809                         vscc
# 13810                          VSE
# 13811                    vsgoftest
# 13812                        vstsr
# 13813                        VSURF
# 13814                       vtable
# 13815                       VTrack
# 13816                       vtreat
# 13817                        vtree
# 13818                         vudc
# 13819                        VWPre
# 13820                          vwr
# 13821                      W2CWM2C
# 13822           W3CMarkupValidator
# 13823                        waccR
# 13824                         WACS
# 13825                      waffect
# 13826                       waffle
# 13827                         wahc
# 13828                       waiter
# 13829                    wakefield
# 13830                  walkalytics
# 13831                       walker
# 13832                 walkscoreAPI
# 13833                      wallace
# 13834                        wally
# 13835                   walmartAPI
# 13836                       walrus
# 13837                      WaMaSim
# 13838                         wand
# 13839                      warbleR
# 13840                         WARN
# 13841                      warpMix
# 13842                     washdata
# 13843                       washeR
# 13844                        wasim
# 13845                        water
# 13846                    waterData
# 13847                    waterfall
# 13848                   waterfalls
# 13849                      WaterML
# 13850                 waterquality
# 13851                   Watersheds
# 13852                waterYearType
# 13853                         Wats
# 13854                     waveband
# 13855                        waved
# 13856                waveformlidar
# 13857                 wavefunction
# 13858                   WaveletANN
# 13859                 WaveletArima
# 13860                  WaveletComp
# 13861            WaveLetLongMemory
# 13862                     wavelets
# 13863                   wavemulcor
# 13864                        waver
# 13865                       WaverR
# 13866                     waveslim
# 13867                   wavethresh
# 13868                 wavScalogram
# 13869                        wBoot
# 13870                          wbs
# 13871                      wbstats
# 13872                        wbsts
# 13873                          WCE
# 13874                          WCM
# 13875                        wCorr
# 13876                          WCQ
# 13877                          WDI
# 13878                          wdm
# 13879                        wdman
# 13880                        wdpar
# 13881                   weathercan
# 13882               weathermetrics
# 13883                     weatherr
# 13884                      webchem
# 13885                       webddx
# 13886                    webdriver
# 13887                        webex
# 13888                  WebGestaltR
# 13889                     webglobe
# 13890                     webmockr
# 13891                         webp
# 13892                     WebPower
# 13893                         webr
# 13894                     webreadr
# 13895                   websearchr
# 13896                      webshot
# 13897                     webTRISr
# 13898                       webuse
# 13899                     webutils
# 13900                          wec
# 13901                         weco
# 13902                        wedge
# 13903                          WEE
# 13904                  weibullness
# 13905                     WeibullR
# 13906                 weibulltools
# 13907           Weighted.Desc.Stat
# 13908              WeightedCluster
# 13909             WeightedPortTest
# 13910                  WeightedROC
# 13911               weightedScores
# 13912                     WeightIt
# 13913                  weightQuant
# 13914                      weightr
# 13915                      weights
# 13916               weightTAPSPACK
# 13917                        weirs
# 13918                     welchADF
# 13919                    wellknown
# 13920                        WeMix
# 13921                  wesanderson
# 13922                        wevid
# 13923                          wfe
# 13924                          wfg
# 13925                       wfindr
# 13926                        wgaim
# 13927                        WGCNA
# 13928                      wgeesel
# 13929                       WhatIf
# 13930                     wheatmap
# 13931                     whereami
# 13932                    whereport
# 13933              whiboclustering
# 13934                      whisker
# 13935                 whitechapelR
# 13936                    whitening
# 13937                  WhiteStripe
# 13938                          WHO
# 13939                       whoami
# 13940                       whoapi
# 13941                   WhopGenome
# 13942                       wicket
# 13943                       widals
# 13944                      widenet
# 13945                  widgetframe
# 13946                        widyr
# 13947                    wikibooks
# 13948        WikidataQueryServiceR
# 13949                    WikidataR
# 13950                     wikilake
# 13951                   WikipediaR
# 13952               wikipediatrend
# 13953                    WikipediR
# 13954                  wikisourcer
# 13955                     wikitaxa
# 13956                     WilcoxCV
# 13957                     wildcard
# 13958                   wildlifeDI
# 13959                    wildpoker
# 13960                       wilson
# 13961                   WindCurves
# 13962                       windex
# 13963                   windfarmGA
# 13964                       wingui
# 13965             winRatioAnalysis
# 13966                         wiod
# 13967                        wiqid
# 13968                        wISAM
# 13969                     WiSEBoot
# 13970                        wiseR
# 13971                        withr
# 13972                          wkb
# 13973                        wktmo
# 13974                        WLreg
# 13975                   WMCapacity
# 13976                         WMDB
# 13977                         wmlf
# 13978                        wmtsa
# 13979                       wmwpow
# 13980                       WMWssp
# 13981                          wnl
# 13982                       wNNSel
# 13983                    wnominate
# 13984                          woe
# 13985                   woeBinning
# 13986                         woeR
# 13987                       womblR
# 13988                   wooldridge
# 13989               word.alignment
# 13990                    wordbankr
# 13991                    wordcloud
# 13992                   wordcloud2
# 13993                    wordmatch
# 13994                      wordnet
# 13995                    WordPools
# 13996                        WordR
# 13997                    wordspace
# 13998                    workflowr
# 13999                     worldmet
# 14000                        worms
# 14001                       worrms
# 14002                         wosr
# 14003                          WPC
# 14004                        wPerm
# 14005                        WPKDE
# 14006                      wpp2008
# 14007                      wpp2010
# 14008                      wpp2012
# 14009                      wpp2015
# 14010                      wpp2017
# 14011                  wppExplorer
# 14012                          wql
# 14013                          wqs
# 14014                      wrangle
# 14015                      Wrapped
# 14016                        wrapr
# 14017                       wrassp
# 14018                    WrightMap
# 14019                   write.snns
# 14020                      writexl
# 14021                     WriteXLS
# 14022                         WRS2
# 14023                         WRSS
# 14024                       wrswoR
# 14025             wrswoR.benchmark
# 14026                   WRTDStidal
# 14027                          wru
# 14028                         wskm
# 14029                         wsrf
# 14030                         wSVM
# 14031                         wsyn
# 14032                        wtest
# 14033                          wTO
# 14034                         wtss
# 14035                       WufooR
# 14036                wunderscraper
# 14037                          wux
# 14038                      WVPlots
# 14039                       wvtool
# 14040                      WWGbook
# 14041                          WWR
# 14042                        x.ent
# 14043                          x12
# 14044                       x12GUI
# 14045                    x13binary
# 14046                     x3ptools
# 14047                     xaringan
# 14048                       xbreed
# 14049                         XBRL
# 14050                    xdcclarge
# 14051                        xergm
# 14052                 xergm.common
# 14053                     xesreadR
# 14054                         xfun
# 14055                      xgb2sql
# 14056                      xgboost
# 14057                        xgobi
# 14058                          XGR
# 14059                  xhmmScripts
# 14060                         XHWE
# 14061                       XiMpLe
# 14062                         xkcd
# 14063                   xkcdcolors
# 14064                     XKCDdata
# 14065                    XLConnect
# 14066                XLConnectJars
# 14067                        xLLiM
# 14068                     xlsimple
# 14069                         xlsx
# 14070                     xlsxjars
# 14071                       xltabr
# 14072                     xlutils3
# 14073                        xmeta
# 14074                        Xmisc
# 14075                          XML
# 14076                         xml2
# 14077                        XML2R
# 14078                 xmlparsedata
# 14079                      xmlrpc2
# 14080                         XMRF
# 14081                         xmrr
# 14082                      XNomial
# 14083                          xoi
# 14084                        xopen
# 14085                       xplain
# 14086                     xplorerr
# 14087                    Xplortext
# 14088                        xpose
# 14089                       xpose4
# 14090                         xptr
# 14091                           XR
# 14092                         xray
# 14093                          xrf
# 14094                        xRing
# 14095                      XRJulia
# 14096                         xROI
# 14097                     XRPython
# 14098                        XRSCC
# 14099                         xseq
# 14100                         xslt
# 14101                          xsp
# 14102                     xspliner
# 14103                         xSub
# 14104                       xtable
# 14105                         xtal
# 14106                      xtensor
# 14107                   xtermStyle
# 14108                 xtractomatic
# 14109                          xts
# 14110                          xVA
# 14111                          xwf
# 14112                        xxIRT
# 14113                     xyloplot
# 14114                          xyz
# 14115                        yacca
# 14116                     yaImpute
# 14117                       yakmoR
# 14118                  YaleToolkit
# 14119                         yaml
# 14120                    yardstick
# 14121                        yarrr
# 14122                         yasp
# 14123                 ycinterextra
# 14124                        yesno
# 14125                         yhat
# 14126                        yhatr
# 14127                   YieldCurve
# 14128                      ykmeans
# 14129                          yll
# 14130                        yorkr
# 14131               youtubecaption
# 14132             YPInterimTesting
# 14133                      YPmodel
# 14134                          ypr
# 14135                       YRmisc
# 14136                       YuGene
# 14137                        yuima
# 14138                     yuimaGUI
# 14139                          yum
# 14140                      yummlyr
# 14141                          Z10
# 14142                        zbank
# 14143                zCompositions
# 14144                      zeallot
# 14145                       ZeBook
# 14146                         zebu
# 14147                     zeitgebr
# 14148                        Zelig
# 14149                  ZeligChoice
# 14150                      ZeligEI
# 14151                   zeligverse
# 14152                     zendeskR
# 14153                     zenplots
# 14154                   zeroEQpart
# 14155                      zetadiv
# 14156                          zfa
# 14157             ZIBBSeqDiscovery
# 14158                       ZIBseq
# 14159                          zic
# 14160                      ZillowR
# 14161                          ZIM
# 14162                          zip
# 14163                      zipcode
# 14164                     zipfextR
# 14165                        zipfR
# 14166                      ziphsmm
# 14167                         zipR
# 14168                    ZipRadius
# 14169                    zoeppritz
# 14170                         zoib
# 14171                         ZOIP
# 14172                          zoo
# 14173                      zooaRch
# 14174                   zooaRchGUI
# 14175                       zoocat
# 14176                     zooimage
# 14177                         zoom
# 14178                     zoomgrid
# 14179                         zoon
# 14180                          ZRA
# 14181                      zscorer
# 14182                         Zseq
# 14183                       ztable
# 14184                        zTree
# 14185                        ztype
# 14186                         ZVCV
# 14187                          zyp
#
#                                                                                                description  \
# 0                                  Accurate, Adaptable, and Accessible Error Metrics for Predictive Models
# 1                                                  Access to Abbyy Optical Character Recognition (OCR) API
# 2                                                         Tools for Approximate Bayesian Computation (ABC)
# 3                                              Data Only: Tools for Approximate Bayesian Computation (ABC)
# 4                                                                 Array Based CpG Region Analysis Pipeline
# 5                                                                                    Computed ABC Analysis
# 6                      ABCDE_FBA: A-Biologist-Can-Do-Everything of Flux Balance Analysis with this package
# 7                                               Implementation of Artificial Bee Colony (ABC) Optimization
# 8                                               Approximate Bayesian Computational Model for Estimating P2
# 9                                                      Approximate Bayesian Computation via Random Forests
# 10                                                                                  Tools for ABC Analyses
# 11                                                                         The Analysis of Biological Data
# 12                                                                          Augmented Backward Elimination
# 13                                                                           Load Gap-Free Axon ABF2 Files
# 14                                                                     Easy Visualization of ABH Genotypes
# 15                                                                         Combine Multidimensional Arrays
# 16                    Useful Tools for Jurimetrical Analysis Used by the Brazilian Jurimetrics Association
# 17                                             Modelling Multivariate Data with Additive Bayesian Networks
# 18                                  Measure a Subject's Abnormality with Respect to a Reference Population
# 19                                                                           Angle-Based Outlier Detection
# 20                                                 The Abnormal Blood Profile Score to Detect Blood Doping
# 21                          Improved False Positive Control of Gene-Permuting GSEA with Absolute Filtering
# 22                                                       Time Resolved Simulations of Antibody Repertoires
# 23                                                    An R-Shiny Application for Creating Visual Abstracts
# 24                                                                                    Bayesian A/B Testing
# 25                                    High-Dimensional Principal Fitted Components and Abundant Regression
# 26                                            Inferring Directional Conservative Causal Core Gene Networks
# 27                                             Abrupt Change-Point or Aberration Detection in Point Series
# 28                                                                            Exploring Accelerometer Data
# 29                                                             Functions for Processing Accelerometer Data
# 30                                                         Missing Value Imputation for Accelerometer Data
# 31                                                    Creation and Evaluation of Acceptance Sampling Plans
# 32                                                                                ACC & LMA Graph Plotting
# 33                                                                             Bayesian Accrual Prediction
# 34                                            Data Quality Visualization Tools for Partially Accruing Data
# 35                                                                Accelerated Sparse Discriminant Analysis
# 36                                            Categorical data analysis with complete or missing responses
# 37                                                    Tools for Autoregressive Conditional Duration Models
# 38                                            Optimal Bayesian Experimental Design using the ACE Algorithm
# 39                                          ACE and AVAS for Selecting Multiple Regression Transformations
# 40                                               Estimating Dynamic Heritability and Twin Model Comparison
# 41                                                              Analysing Conditional Income Distributions
# 42                                                         Align-and-Count Method comparisons of RFLP data
# 43                               Estimation of Interpretable eQTL Effect Sizes Using a Log of Linear Model
# 44                                    Implements ACME Estimator of Bird and Bat Mortality by Wind Turbines
# 45                              Affymetrix SNP Probe-Summarization using Non-Negative Matrix Factorization
# 46                                                                           Annotated Copy-Number Regions
# 47                Modelling Dependence with Multivariate Archimax (or any User-Defined Continuous) Copulas
# 48                                                                     Coding Sound Files for Use with NDL
# 49                                                                      Autoregressive Conditional Poisson
# 50                                   Convenience functions for analytical Customer Relationship Management
# 51                                                 A Cost-Minimal Regular Spanning Subgraph with TreeClust
# 52                                                                          Autocorrelation Robust Testing
# 53       Download, Manipulate, and Present American Community Survey and Decennial Data from the US Census
# 54                                                    Gene Enrichment Analysis from ACSN Maps or GMT Files
# 55                                                                Algorithmic Complexity for Short Strings
# 56                 Data Only: Algorithmic Complexity of Short Strings (Computed via Coding Theorem Method)
# 57                                        A Companion Package for the Book "A Course in Statistics with R"
# 58                                                Asymptotic Classification Theory for Cognitive Diagnosis
# 59                                                                                Actigraphy Data Analysis
# 60         Finding Cancer Driver Proteins with Enriched Mutations in Post-Translational Modification Sites
# 61                                                        A Driver Discovery Tool for Cancer Whole Genomes
# 62                                                                Multivariate Pathway Enrichment Analysis
# 63                                                                              Animal Activity Statistics
# 64                                                 Activity Index Calculation using Raw Accelerometry Data
# 65                                                                           Process activPAL Events Files
# 66                                                                Read in Activity Data and Plot Actograms
# 67                                                      Actuarial Functions and Heavy Tailed Distributions
# 68                A Package for Displaying Visual Scenes as They May Appear to an Animal with Lower Acuity
# 69                                                               The R Package Ada for Stochastic Boosting
# 70                                                       Applies Multiclass AdaBoost.M1, SAMME and Bagging
# 71                                                               Discrete and Global Optimization Routines
# 72                                                            Archetypoid Algorithms and Anomaly Detection
# 73                                               A Class of Adaptive Elastic Net Methods for Censored Data
# 74                                                  Implementation of an Accountable Data Analysis Process
# 75                                                                            Adaptive Sampling Algorithms
# 76                                                                             Check Code Style Painlessly
# 77                                                                       Adaptive Semiparametic Regression
# 78     Adaptive Semiparametric Additive Regression with Simultaneous Confidence Bands and Specification...
# 79                                                                           Gaussian Mixture Models (GMM)
# 80                                                                                Adaptive Generalized PCA
# 81                                                                                Adaptive Sparsity Models
# 82                                                                       Tau-Leaping Stochastic Simulation
# 83                                   Implementation of a Generic Adaptive Monte Carlo Markov Chain Sampler
# 84                     Adaptive P-Value Thresholding for Multiple Hypothesis Testing with Side Information
# 85                                                                         Adaptive Smoothing of FMRI Data
# 86                                                                                Adaptive two-stage tests
# 87                                       Adaptive Sampling for Positive Unlabeled and Label Noise Learning
# 88                                                                      Adaptive Design in Clinical Trials
# ...
# 14042                                                                                 extraction of entity
# 14043  interface to 'x12-arima'/'x13-arima-seats' and structure for batch processing of seasonal adjust...
# 14044                                                                       x12 - graphical user interface
# 14045                                                   provide the 'x13ashtml' seasonal adjustment binary
# 14046                                                       tools for working with 3d surface measurements
# 14047                                                                                   presentation ninja
# 14048                                             genomic simulation of purebred and crossbred populations
# 14049                                   extraction of business financial information from 'xbrl' documents
# 14050                                                  estimating a (c)dcc-garch model in large dimensions
# 14051                                                        extensions of exponential random graph models
# 14052                              common infrastructure for extensions of exponential random graph models
# 14053                                                                             read and write xes files
# 14054                                                               miscellaneous functions by 'yihui xie'
# 14055                                                         convert trained 'xgboost' model to sql query
# 14056                                                                            extreme gradient boosting
# 14057                                interface to the xgobi and xgvis programs for graphical data analysis
# 14058  exploring genomic relations for enhanced interpretation through enrichment, similarity, network ...
# 14059                                                                                       xhmm r scripts
# 14060                                                              x chromosome hardy-weinberg equilibrium
# 14061                                                               a simple xml tree parser and generator
# 14062                                                           plotting ggplot2 graphics in an xkcd style
# 14063                                                               color names from the xkcd color survey
# 14064                                                                                  get xkcd comic data
# 14065                                                                                excel connector for r
# 14066                                                           jar dependencies for the xlconnect package
# 14067                                                              high dimensional locally-linear mapping
# 14068                                                                                  'xlconnect' wrapper
# 14069                                       read, write, format excel 2007 and excel 97/2000/xp/2003 files
# 14070                                                       package required poi jars for the xlsx package
# 14071              automatically write beautifully formatted cross tabulations/contingency tables to excel
# 14072                                                                 extract multiple excel files at once
# 14073                                                             a toolbox for multivariate meta-analysis
# 14074                                                        xiaobei's miscellaneous classes and functions
# 14075                                             tools for parsing and generating xml within r and s-plus
# 14076                                                                                            parse xml
# 14077                                                                           easier xml data collection
# 14078                                                              parse data of 'r' code as an 'xml' tree
# 14079                                     implementation of the remote procedure call protocol ('xml-rpc')
# 14080                                               markov random fields for high-throughput genetics data
# 14081                                                generate xmr control chart data from time-series data
# 14082                             exact goodness-of-fit test for multinomial data with fixed probabilities
# 14083                                                           tools for analyzing crossover interference
# 14084                                                                  open system files, 'urls', anything
# 14085                        providing interactive interpretations and explanations of statistical results
# 14086                                                               tools for interactive data exploration
# 14087                                                                 statistical analysis of textual data
# 14088                                                                diagnostics for pharmacometric models
# 14089                                      tools for nonlinear mixed-effect model building and diagnostics
# 14090                                                                        manipulating external pointer
# 14091                                                                    a structure for interfaces from r
# 14092                                                                        x ray vision on your datasets
# 14093                                                                                      extreme rulefit
# 14094                                         visualization and correction of x-ray micro-density profiles
# 14095                                                                        structured interface to julia
# 14096  delineate region of interests (roi's) and extract time-series data from digital repeat photograp...
# 14097                                                                     structured interface to 'python'
# 14098                                                               statistical quality control simulation
# 14099                                assessing functional impact on gene expression of mutations in cancer
# 14100                                                      extensible style-sheet language transformations
# 14101                                                                           the chi-square periodogram
# 14102  assisted model building, using surrogate black-box models to train interpretable spline based ad...
# 14103                                                         cross-national data on sub-national violence
# 14104                                                                       export tables to latex or html
# 14105                                                                              crystallization toolset
# 14106                                                                    headers for the 'xtensor' library
# 14107                                                      terminal text formatting using escape sequences
# 14108                                                accessing environmental data from erd's erddap server
# 14109                                                                               extensible time series
# 14110                                                         calculates credit risk valuation adjustments
# 14111                                                                  extrema-weighted feature extraction
# 14112                                                 item response theory and computer-based testing in r
# 14113                                         a method for creating xylophone-like frequency density plots
# 14114                             the 'xyz' algorithm for fast interaction search in high-dimensional data
# 14115                                                   yet another canonical correlation analysis package
# 14116                                         nearest neighbor observation imputation and evaluation tools
# 14117                                                       a simple wrapper for the k-means library yakmo
# 14118                                                          data exploration tools from yale university
# 14119                                                           methods to convert r data to yaml and back
# 14120                                                          tidy characterizations of model performance
# 14121                                          a companion to the e-book "yarrr!: the pirate's guide to r"
# 14122                                                                  string functions for compact r code
# 14123                                    yield curve or zero-coupon prices interpolation and extrapolation
# 14124                                                                                 ask yes-no questions
# 14125                                                                      interpreting regression effects
# 14126                                                                            r binder for the yhat api
# 14127                                                          modelling and estimation of the yield curve
# 14128                                                                      k-means using a target variable
# 14129                                            compute expected years of life lost (yll) and average yll
# 14130                                            analyze cricket performances based on data from cricsheet
# 14131                             downloading youtube subtitle transcription in a tidy 'tibble' data_frame
# 14132                        interim monitoring using adaptively weighted log-rank test in clinical trials
# 14133                                    the short-term and long-term hazard ratio model for survival data
# 14134                                                                                    yield per recruit
# 14135                                                                        y&r miscellaneous r functions
# 14136  a simple approach to scale gene expression data derived from different platforms for integrated ...
# 14137                                                                   the yuima project package for sdes
# 14138                                                   a graphical user interface for the 'yuima' package
# 14139                                                    utilities to extract and process 'yaml' fragments
# 14140                                                                            r bindings for yummly api
# 14141                                                   simple ecological statistics from the neon network
# 14142                                                                                 'zoobank' api client
# 14143                      treatment of zeros, left-censored and missing values in compositional data sets
# 14144                                                    multiple, unpacking, and destructuring assignment
# 14145                                          working with dynamic models for agriculture and environment
# 14146                                                                           local association measures
# 14147                                                                     analysis of circadian behaviours
# 14148                                                                      everyone's statistical software
# 14149                                                                                  zelig choice models
# 14150                                                                    zelig ecological inference models
# 14151                                                        easily install and load stable zelig packages
# 14152                                                                                  zendesk api wrapper
# 14153                                                                     zigzag expanded navigation plots
# 14154                                                 zero order vs (semi) partial correlation test and ci
# 14155                                     functions to compute compositional turnover using zeta diversity
# 14156                                                                                 zoom-focus algorithm
# 14157                                        zero-inflated beta-binomial modeling of microbiome count data
# 14158               differential abundance analysis for metagenomic data via zero-inflated beta regression
# 14159                                                    bayesian inference for zero-inflated count models
# 14160                                              r interface to zillow real estate and mortgage data api
# 14161                                   zero-inflated models (zim) for count time series with excess zeros
# 14162                                                                     cross-platform 'zip' compression
# 14163                                                                 u.s. zip code database for geocoding
# 14164                                                                          zipf extended distributions
# 14165                                                  statistical models for word frequency distributions
# 14166                                                    zero-inflated poisson hidden (semi-)markov models
# 14167                                                                                 pythonic zip() for r
# 14168                      creates a data frame of us zip codes in a given radius from a given us zip code
# 14169                                                       seismic reflection and scattering coefficients
# 14170                      bayesian inference for beta regression and zero-or-one inflated beta regression
# 14171                                            zoip distribution, zoip regression, zoip mixed regression
# 14172                   s3 infrastructure for regular and irregular time series (z's ordered observations)
# 14173                                                          analytical tools for zooarchaeological data
# 14174                                              interactive analytical tools for zooarchaeological data
# 14175                                                                 'zoo' objects with column attributes
# 14176                                                                analysis of numerical plankton images
# 14177                                                                    a spatial data visualization tool
# 14178                                                                    grid search algorithm with a zoom
# 14179                                  reproducible, accessible & shareable species distribution modelling
# 14180                                                            dynamic plots for time series forecasting
# 14181                                                               child anthropometry z-score calculator
# 14182                                                                           integer sequence generator
# 14183                                                       zebra-striped tables in latex and html formats
# 14184                                                        functions to import data from 'z-tree' into r
# 14185                                                             run a ztype game loaded with r functions
# 14186                                                                       zero-variance control variates
# 14187                                                                     zhang + yue-pilon trends package
#
# [14188 rows x 5 columns]

# %%
pd.set_option('display.max_colwidth', 100)

df_init = pd.DataFrame(columns=['name', 'description', 'keywords', 'url'])

for i, keyword in enumerate(keywords):
    
    keys = " ".join(keyword)
    
    print('======================================================')
    print(f'Table {i+1} - keywords: {keys} \n')
    
    
    for j, word in enumerate(keyword):
        print(f'Checking for word {word}')
        check = df.description_lower.str.contains(word)
        print(f'Number of matches: {sum(check)}\n')
        if j == 0:
            check_combined = check 
        else:
            check_combined = check & check_combined
    
    df_filtered = df[check_combined][['name', 'description', 'url']]
    print(df[check_combined][['name']])
    df_filtered = df_filtered.assign(keywords=keys)
    df_init = df_init.append(df_filtered, sort=True)
    print(f'\nTotal: {df_filtered.shape}')
    print('\n\n')
# Out:
# ======================================================
# Table 1 - keywords: species distribution
#
# Checking for word species
# Number of matches: 87
#
# Checking for word distribution
# Number of matches: 381
#
#                  name
# 1018          biomod2
# 2838            dismo
# 4254         fuzzySim
# 4286           gambin
# 5345             hSDM
# 5829             iSDM
# 6789      marinespeed
# 6858          maxlike
# 6861           maxnet
# 7196          MigClim
# 7498             mopa
# 11305          SADISA
# 11307            sads
# 11501             sdm
# 11502         SDMPlay
# 11503   sdmpredictors
# 11504        SDMTools
# 11505     sdmvspecies
# 11512          sdStaf
# 12319     SPEDInstabR
# 12450            SSDM
# 12452        ssdtools
# 13610            usdm
# 13761  virtualspecies
# 13833         wallace
# 14179            zoon
#
# Total: (26, 4)
#
#
#
# ======================================================
# Table 2 - keywords: SDM
#
# Checking for word SDM
# Number of matches: 0
#
# Empty DataFrame
# Columns: [name]
# Index: []
#
# Total: (0, 4)
#
#
#
# ======================================================
# Table 3 - keywords: niche
#
# Checking for word niche
# Number of matches: 9
#
#                           name
# 1533                     CENFA
# 3407                     ENiRG
# 3408                   ENMeval
# 3442                 EnvNicheR
# 6855   MaxentVariableSelection
# 8005                nicheROVER
# 8955                 phyloclim
# 10641                     rKIN
# 13833                  wallace
#
# Total: (9, 4)
#
#
#
# ======================================================
# Table 4 - keywords: species range
#
# Checking for word species
# Number of matches: 87
#
# Checking for word range
# Number of matches: 27
#
#                     name
# 1199            bossMaps
# 9887        rangeBuilder
# 9889  rangeModelMetadata
#
# Total: (3, 4)
#
#
#
# ======================================================
# Table 5 - keywords: species occupancy
#
# Checking for word species
# Number of matches: 87
#
# Checking for word occupancy
# Number of matches: 6
#
#                     name
# 2882  DiversityOccupancy
# 2973           downscale
#
# Total: (2, 4)
#
#
#
# ======================================================
# Table 6 - keywords: species diversity extrapolation
#
# Checking for word species
# Number of matches: 87
#
# Checking for word diversity
# Number of matches: 49
#
# Checking for word extrapolation
# Number of matches: 11
#
#        name
# 5642  iNEXT
#
# Total: (1, 4)

# %%
uniques = df_init[~df_init['name'].duplicated()]
dups = df_init[df_init['name'].duplicated()]

# %%
dups
# Out:
#                                                                             description  \
# 13833  A Modular Platform for Reproducible Modeling of Species Niches and Distributions
#
#       keywords     name  \
# 13833    niche  wallace
#
#                                                               url
# 13833  https://cran.r-project.org/web/packages/wallace/index.html

# %%
for i, row in dups.iterrows():
    print(i, row['name'])
    uniques.at[uniques.name==row['name'], 'keywords'] = \
        ''.join(list(uniques[uniques.name==row['name']]['keywords'])) + f'; {row["keywords"]}'
# Out:
# 13833 wallace
# /home/euniceesh/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/euniceesh/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:2823: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.loc[index, col] = value

# %%
uniques[uniques.name.isin(list(dups.name))]
# Out:
#                                                                             description  \
# 13833  A Modular Platform for Reproducible Modeling of Species Niches and Distributions
#
#                           keywords     name  \
# 13833  species distribution; niche  wallace
#
#                                                               url
# 13833  https://cran.r-project.org/web/packages/wallace/index.html

# %%
uniques = uniques.assign(prog_lang='R', source='CRAN', stars="nan")
uniques = uniques[['name', 'description', 'url', 'keywords', 'prog_lang', 'source', 'stars']]
uniques.to_csv(f'data-out/pkgs-cran-{date}.csv', index=False)

# %%
uniques
# Out:
#                           name  \
# 1018                   biomod2
# 2838                     dismo
# 4254                  fuzzySim
# 4286                    gambin
# 5345                      hSDM
# 5829                      iSDM
# 6789               marinespeed
# 6858                   maxlike
# 6861                    maxnet
# 7196                   MigClim
# 7498                      mopa
# 11305                   SADISA
# 11307                     sads
# 11501                      sdm
# 11502                  SDMPlay
# 11503            sdmpredictors
# 11504                 SDMTools
# 11505              sdmvspecies
# 11512                   sdStaf
# 12319              SPEDInstabR
# 12450                     SSDM
# 12452                 ssdtools
# 13610                     usdm
# 13761           virtualspecies
# 13833                  wallace
# 14179                     zoon
# 1533                     CENFA
# 3407                     ENiRG
# 3408                   ENMeval
# 3442                 EnvNicheR
# 6855   MaxentVariableSelection
# 8005                nicheROVER
# 8955                 phyloclim
# 10641                     rKIN
# 1199                  bossMaps
# 9887              rangeBuilder
# 9889        rangeModelMetadata
# 2882        DiversityOccupancy
# 2973                 downscale
# 5642                     iNEXT
#
#                                                                                                description  \
# 1018                                                   Ensemble Platform for Species Distribution Modeling
# 2838                                                                         Species Distribution Modeling
# 4254                                                             Fuzzy Similarity in Species Distributions
# 4286                                               Fit the Gambin Model to Species Abundance Distributions
# 5345                                                     Hierarchical Bayesian Species Distribution Models
# 5829                                                               Invasive Species Distribution Modelling
# 6789                           Benchmark Data Sets and Functions for Marine Species Distribution Modelling
# 6858      Model Species Distributions by Estimating the Probability of Occurrence Using Presence-Only Data
# 6861                                            Fitting 'Maxent' Species Distribution Models with 'glmnet'
# 7196                                               Implementing dispersal into species distribution models
# 7498                                                    Species Distribution MOdeling with Pseudo-Absences
# 11305                                  Species Abundance Distributions with Independent-Species Assumption
# 11307                                        Maximum Likelihood Models for Species Abundance Distributions
# 11501                                                                       Species Distribution Modelling
# 11502                                                            Species Distribution Modelling Playground
# 11503                                                    Species Distribution Modelling Predictor Datasets
# 11504  Species Distribution Modelling Tools: Tools for processing data associated with species distribu...
# 11505                                            Create Virtual Species for Species Distribution Modelling
# 11512                                                     Species Distribution and Stability Future Models
# 12319  Estimation of the Relative Importance of Factors Affecting Species Distribution Based on Stabili...
# 12450                                                               Stacked Species Distribution Modelling
# 12452                                                                    Species Sensitivity Distributions
# 13610                                                 Uncertainty Analysis for Species Distribution Models
# 13761                                                          Generation of Virtual Species Distributions
# 13833                     A Modular Platform for Reproducible Modeling of Species Niches and Distributions
# 14179                                  Reproducible, Accessible & Shareable Species Distribution Modelling
# 1533                                                          Climate and Ecological Niche Factor Analysis
# 3407                                                                       Ecological Niche in R and GRASS
# 3408                                             Automated Runs and Evaluations of Ecological Niche Models
# 3442                                                                                      Niche Estimation
# 6855   Selecting the Best Set of Relevant Environmental Variables along with the Optimal Regularization...
# 8005                   (Niche) (R)egion and Niche (Over)lap Metrics for Multidimensional Ecological Niches
# 8955                                                 Integrating Phylogenetics and Climatic Niche Modeling
# 10641                                                                    (Kernel) Isotope Niche Estimation
# 1199            Convert Binary Species Range Maps into Continuous Surfaces Based on Distance to Range Edge
# 9887   Occurrence Filtering, Geographic and Taxonomic Standardization and Generation of Species Range P...
# 9889                            Provides Templates for Metadata Files Associated with Species Range Models
# 2882                                      Building Diversity Models from Multiple Species Occupancy Models
# 2973                                                                         Downscaling Species Occupancy
# 5642                                                 Interpolation and Extrapolation for Species Diversity
#
#                                                                               url  \
# 1018                   https://cran.r-project.org/web/packages/biomod2/index.html
# 2838                     https://cran.r-project.org/web/packages/dismo/index.html
# 4254                  https://cran.r-project.org/web/packages/fuzzySim/index.html
# 4286                    https://cran.r-project.org/web/packages/gambin/index.html
# 5345                      https://cran.r-project.org/web/packages/hSDM/index.html
# 5829                      https://cran.r-project.org/web/packages/iSDM/index.html
# 6789               https://cran.r-project.org/web/packages/marinespeed/index.html
# 6858                   https://cran.r-project.org/web/packages/maxlike/index.html
# 6861                    https://cran.r-project.org/web/packages/maxnet/index.html
# 7196                   https://cran.r-project.org/web/packages/MigClim/index.html
# 7498                      https://cran.r-project.org/web/packages/mopa/index.html
# 11305                   https://cran.r-project.org/web/packages/SADISA/index.html
# 11307                     https://cran.r-project.org/web/packages/sads/index.html
# 11501                      https://cran.r-project.org/web/packages/sdm/index.html
# 11502                  https://cran.r-project.org/web/packages/SDMPlay/index.html
# 11503            https://cran.r-project.org/web/packages/sdmpredictors/index.html
# 11504                 https://cran.r-project.org/web/packages/SDMTools/index.html
# 11505              https://cran.r-project.org/web/packages/sdmvspecies/index.html
# 11512                   https://cran.r-project.org/web/packages/sdStaf/index.html
# 12319              https://cran.r-project.org/web/packages/SPEDInstabR/index.html
# 12450                     https://cran.r-project.org/web/packages/SSDM/index.html
# 12452                 https://cran.r-project.org/web/packages/ssdtools/index.html
# 13610                     https://cran.r-project.org/web/packages/usdm/index.html
# 13761           https://cran.r-project.org/web/packages/virtualspecies/index.html
# 13833                  https://cran.r-project.org/web/packages/wallace/index.html
# 14179                     https://cran.r-project.org/web/packages/zoon/index.html
# 1533                     https://cran.r-project.org/web/packages/CENFA/index.html
# 3407                     https://cran.r-project.org/web/packages/ENiRG/index.html
# 3408                   https://cran.r-project.org/web/packages/ENMeval/index.html
# 3442                 https://cran.r-project.org/web/packages/EnvNicheR/index.html
# 6855   https://cran.r-project.org/web/packages/MaxentVariableSelection/index.html
# 8005                https://cran.r-project.org/web/packages/nicheROVER/index.html
# 8955                 https://cran.r-project.org/web/packages/phyloclim/index.html
# 10641                     https://cran.r-project.org/web/packages/rKIN/index.html
# 1199                  https://cran.r-project.org/web/packages/bossMaps/index.html
# 9887              https://cran.r-project.org/web/packages/rangeBuilder/index.html
# 9889        https://cran.r-project.org/web/packages/rangeModelMetadata/index.html
# 2882        https://cran.r-project.org/web/packages/DiversityOccupancy/index.html
# 2973                 https://cran.r-project.org/web/packages/downscale/index.html
# 5642                     https://cran.r-project.org/web/packages/iNEXT/index.html
#
#                               keywords prog_lang source stars
# 1018              species distribution         R   CRAN   nan
# 2838              species distribution         R   CRAN   nan
# 4254              species distribution         R   CRAN   nan
# 4286              species distribution         R   CRAN   nan
# 5345              species distribution         R   CRAN   nan
# 5829              species distribution         R   CRAN   nan
# 6789              species distribution         R   CRAN   nan
# 6858              species distribution         R   CRAN   nan
# 6861              species distribution         R   CRAN   nan
# 7196              species distribution         R   CRAN   nan
# 7498              species distribution         R   CRAN   nan
# 11305             species distribution         R   CRAN   nan
# 11307             species distribution         R   CRAN   nan
# 11501             species distribution         R   CRAN   nan
# 11502             species distribution         R   CRAN   nan
# 11503             species distribution         R   CRAN   nan
# 11504             species distribution         R   CRAN   nan
# 11505             species distribution         R   CRAN   nan
# 11512             species distribution         R   CRAN   nan
# 12319             species distribution         R   CRAN   nan
# 12450             species distribution         R   CRAN   nan
# 12452             species distribution         R   CRAN   nan
# 13610             species distribution         R   CRAN   nan
# 13761             species distribution         R   CRAN   nan
# 13833      species distribution; niche         R   CRAN   nan
# 14179             species distribution         R   CRAN   nan
# 1533                             niche         R   CRAN   nan
# 3407                             niche         R   CRAN   nan
# 3408                             niche         R   CRAN   nan
# 3442                             niche         R   CRAN   nan
# 6855                             niche         R   CRAN   nan
# 8005                             niche         R   CRAN   nan
# 8955                             niche         R   CRAN   nan
# 10641                            niche         R   CRAN   nan
# 1199                     species range         R   CRAN   nan
# 9887                     species range         R   CRAN   nan
# 9889                     species range         R   CRAN   nan
# 2882                 species occupancy         R   CRAN   nan
# 2973                 species occupancy         R   CRAN   nan
# 5642   species diversity extrapolation         R   CRAN   nan
